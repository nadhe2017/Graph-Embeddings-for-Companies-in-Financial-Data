# %%
from selenium import webdriver
from HTMLParser import HTMLParser
# from bs4 import BeautifulSoup
import unidecode

# %%
chrome_path = "/Users/jiayi666/Applications/Google\ Chrome.app/Contents/MacOS/Google\ Chrome"
driver_path = "/Users/jiayi666/Downloads/chromedriver"

# %%
options = webdriver.ChromeOptions()
options.binary_location = chrome_path
# browser = webdriver.Chrome(driver_path, chrome_options=options)
browser = webdriver.Chrome(driver_path)

# %%
url = "https://www.bloomberg.com/research//common/symbollookup/symbollookup.asp?region=all&letterIn=abc+cap&lookuptype=private"
browser.get(url)
x = HTMLParser().unescape(unidecode.unidecode(unicode(browser.page_source)))
# x = BeautifulSoup(unidecode.unidecode(unicode(browser.page_source)))
print x
# Out:
# <!DOCTYPE html><html xmlns="http://www.w3.org/1999/xhtml"><head><style class="vjs-styles-defaults">
#       .video-js {
#         width: 300px;
#         height: 150px;
#       }
#
#       .vjs-fluid {
#         padding-top: 56.25%
#       }
#     </style><style class="vjs-styles-dimensions">
#       .bvp-bb-min-159252-dimensions {
#         width: 100px;
#         height: 57px;
#       }
#
#       .bvp-bb-min-159252-dimensions.vjs-fluid {
#         padding-top: 56.25%;
#       }
# ...

# %%
from fake_useragent import UserAgent
import requests

# %%
ua = UserAgent()
print(ua.chrome)
header = {'User-Agent':str(ua.chrome)}
print(header)
# url = "https://www.hybrid-analysis.com/recent-submissions?filter=file&sort=^timestamp"
url = "https://www.bloomberg.com/research//common/symbollookup/symbollookup.asp?region=Americas&textIn=abc&x=19&y=19&lookuptype=private"
htmlContent = requests.get(url, headers=header)
print(htmlContent)
print(htmlContent.content)
# Out:
# Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.67 Safari/537.36
# {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2227.0 Safari/537.36'}
# <Response [200]>
# <!doctype html>
# <html>
# <head>
#     <title>Bloomberg - Are you a robot?</title>
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#     <link rel="stylesheet" type="text/css" href="https://assets.bwbx.io/font-service/css/BWHaasGrotesk-55Roman-Web,BWHaasGrotesk-75Bold-Web,BW%20Haas%20Text%20Mono%20A-55%20Roman/font-face.css">
#     <style rel="stylesheet" type="text/css">
#         html, body, div, span, applet, object, iframe,
#         h1, h2, h3, h4, h5, h6, p, blockquote, pre,
#         a, abbr, acronym, address, big, cite, code,
#         del, dfn, em, img, ins, kbd, q, s, samp,
#         small, strike, strong, sub, sup, tt, var,
#         b, u, i, center,
#         dl, dt, dd, ol, ul, li,
# ...
