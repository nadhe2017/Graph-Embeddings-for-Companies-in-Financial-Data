# %%
from bs4 import BeautifulSoup
# from urllib.request import urlopen
from selenium import webdriver
from html.parser import HTMLParser
import unidecode
import re
import os
import time
import random

# %%
# import winsound
def got_CAPTCHA(soup):
    if 'Are you a robot?' in soup.title.text:
#         winsound.Beep(300, 2000)
        while(1):
            try:
                input("Have you solved the captcha? Enter a number to proceed. ")
                return True
            except NameError:
                print ("Don't forget the quotes if entering a character!")
                pass
    else:
        return False

# %%
name_list = ["Aedan Financial Corp",\
             "A Self-Administered Real Estate Investment Trust Inc."]
search_url1 = "https://www.bloomberg.com/research//common/symbollookup/symbollookup.asp?region=ALL&textIn="
# first+second+third
search_url2_private = "&lookuptype=private"
search_url2_public = "&lookuptype=public"

# %%
# launch selenium browser
driver_path = "/Users/jiayi666/Downloads/chromedriver"
browser = webdriver.Chrome(driver_path)
random.seed(123)

# %%
def get_search_result(url):
    wait = random.random()
    time.sleep(wait)
    browser.get(url)
    soup = BeautifulSoup(browser.page_source)
    while got_CAPTCHA(soup):
        browser.get(url)
        soup = BeautifulSoup(browser.page_source)
    # find table
    table = soup.find("table",{"class":"table"})
    return table

# %%
# name = "Aedan Financial Corp"
# name = "Blue Buffalo"
for name in name_list:
    url = search_url1 + "+".join(name.split()) + search_url2_private
#     print(url)
    # render page
    table = get_search_result(url)
    if not table.find("tbody").find("td",{"class":"noData"}): # found in private companies
        print("Private Company:")
        link = table.find("tbody").find("tr").find("a")["href"]
        pre_url = "https://www.bloomberg.com/research/"
        comp_url = pre_url+link[6:]
        print(comp_url)
        # render new page and get bDesc
        wait = random.random()
        time.sleep(wait)
        browser.get(comp_url)
        soup = BeautifulSoup(browser.page_source)
        while got_CAPTCHA(soup):
            browser.get(comp_url)
            soup = BeautifulSoup(browser.page_source)
    #     print(soup.prettify)
        desc = soup.find("p",{"id":"bDesc"}).text
        print(desc)
    else:
        url = search_url1 + "+".join(name.split()) + search_url2_public
        table = get_search_result(url)
        if not table.find("tbody").find("td",{"class":"noData"}): # found in public companies
            print("Public Company:")
            link = table.find("tbody").find("tr").find("a")["href"]
            pre_url = "https://www.bloomberg.com/research/"
            comp_url = pre_url+link[6:]
            print(comp_url)
            wait = random.random()
            time.sleep(wait)
            browser.get(comp_url)
            soup = BeautifulSoup(browser.page_source)
            while got_CAPTCHA(soup):
                browser.get(comp_url)
                soup = BeautifulSoup(browser.page_source)
        #     print(soup.prettify)
#             desc = soup.find("section",{"class":"description"}).find("p").text
            desc = soup.find("section",{"class":re.compile("left__.{0,10} description__.{0,10}")}).text
            print(desc)
        else:
            print("This company wasn't found.")
            # deal with companies didn't find
# Out:
# Private Company:
# https://www.bloomberg.com/research/stocks/private/snapshot.asp?privcapId=529906283
# Have you solved the captcha? Enter a number to proceed. “y"
# Aedan Financial Corp was formerly known as Tulip Grove Acquisition Corp.
# Public Company:
# https://www.bloomberg.com/research/stocks/snapshot/snapshot.asp?ticker=140910:KS
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-733dc58c67be> in <module>()
#      41         #     print(soup.prettify)
#      42 #             desc = soup.find("section",{"class":"description"}).find("p").text
# ---> 43             desc = soup.find("section",{"class":re.compile("left__* description__*")}).find("p").text
#      44             print(desc)
#      45         else:
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html lang="en" xmlns="http://www.w3.org/1999/xhtml"><head><style class="vjs-styles-defaults">
#       .video-js {
#         width: 300px;
#         height: 150px;
#       }
#
#       .vjs-fluid {
#         padding-top: 56.25%
#       }
#     </style><style class="vjs-styles-dimensions">
#       .bvp-bvp_pl-804992-dimensions {
#         width: 300px;
#         height: 168.75px;
#       }
#
#       .bvp-bvp_pl-804992-dimensions.vjs-fluid {
#         padding-top: 56.25%;
#       }
#     </style>
# <title>140910:Korea SE Stock Quote - A Self-Administered Real Estate Investment Trust Inc - Bloomberg Markets</title>
# <meta content="140910:Korea SE Stock Quote - A Self-Administered Real Estate Investment Trust Inc" name="title"/>
# <script async="" src="https://s0.2mdn.net/instream/video/client.js" type="text/javascript"></script><script src="https://securepubads.g.doubleclick.net/gpt/pubads_impl_rendering_2019032901.js"></script><script src="https://pagead2.googlesyndication.com/pagead/show_companion_ad.js"></script><script async="" src="https://sb.scorecardresearch.com/beacon.js"></script><script async="" src="//www.google-analytics.com/analytics.js"></script><script async="" src="https://sb.scorecardresearch.com/beacon.js"></script><script charset="UTF-8" src="https://cdn.taboola.com/libtrc/impl.352-125-RELEASE.js" type="text/javascript"></script><script async="" src="//widget.perfectmarket.com/bloomberg/load.js"></script><script async="" src="https://ml314.com/tag.aspx?93"></script><script src="https://login.bloomberg.com/user-info?callback=__jp0"></script><script async="" src="/8FCGYgk4/init.js"></script><script async="" id="piano-io-script" src="//cdn.tinypass.com/api/tinypass.min.js" type="text/javascript"></script><script async="" src="https://snap.licdn.com/li.lms-analytics/insight.min.js" type="text/javascript"></script><script async="" src="//bat.bing.com/bat.js"></script><script async="" src="https://s.yimg.com/wi/ytc.js"></script><script async="" src="https://a2.adform.net/serving/scripts/trackpoint/async/" type="text/javascript"></script><script async="" src="https://a.quora.com/qevents.js"></script><script async="" src="//static.ads-twitter.com/uwt.js"></script><script async="" src="https://snap.licdn.com/li.lms-analytics/insight.min.js" type="text/javascript"></script><script async="" src="https://connect.facebook.net/signals/config/1888404258117965?v=2.8.46&amp;r=stable"></script><script async="" src="https://connect.facebook.net/signals/config/239834876761399?v=2.8.46&amp;r=stable"></script><script async="" src="https://connect.facebook.net/signals/config/407225039721182?v=2.8.46&amp;r=stable"></script><script async="" src="https://connect.facebook.net/signals/config/114475372488961?v=2.8.46&amp;r=stable"></script><script async="" src="https://connect.facebook.net/en_US/fbevents.js"></script><script async="" src="/8FCGYgk4/init.js"></script><script async="" src="//www.googleadservices.com/pagead/conversion_async.js" type="text/javascript"></script><script async="" src="//www.googleadservices.com/pagead/conversion_async.js" type="text/javascript"></script><script async="" src="//www.googleadservices.com/pagead/conversion_async.js" type="text/javascript"></script><script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" id="fence-snippet" src="//assets.bwbx.io/s3/fence/v4/app.bundle.js"></script><script defer="" src="https://www.googletagmanager.com/gtm.js?id=GTM-MNTH5N"></script><script async="" id="tb_loader_script" src="//cdn.taboola.com/libtrc/bloomberg/loader.js"></script><script type="application/ld+json">{"@context":"http://schema.org","@type":"WebPage","headline":"140910:Korea SE Stock Quote - A Self-Administered Real Estate Investment Trust Inc","description":"Stock analysis for A Self-Administered Real Estate Investment Trust Inc (140910:Korea SE) including stock price, stock chart, company news, key statistics, fundamentals and company profile.","keywords":"A Self-Administered Real Estate Investment Trust Inc, A Self-Administered Real Estate Investment Trust Inc stock, A Self-Administered Real Estate Investment Trust Inc stock price, A Self-Administered Real Estate Investment Trust Inc stock charts, 140910 price quote, 140910 quote, A Self-Administered Real Estate Investment Trust Inc news, 140910, 140910 stock, 140910 stock price, 140910 stock charts, stock, stock price, stock charts","mainEntityOfPage":"https://www.bloomberg.com/quote/140910:KS","mentions":[{"@type":"Thing","name":"financials","url":"https://www.bloomberg.com/markets/sectors/financials"},{"@type":"Thing","name":"A Self-Administered Real Estate Investment Trust Inc","url":"https://www.bloomberg.com/pr ...
# <meta content="Stock analysis for A Self-Administered Real Estate Investment Trust Inc (140910:Korea SE) including stock price, stock chart, company news, key statistics, fundamentals and company profile." name="description"/>
# <meta content="A Self-Administered Real Estate Investment Trust Inc, A Self-Administered Real Estate Investment Trust Inc stock, A Self-Administered Real Estate Investment Trust Inc stock price, A Self-Administered Real Estate Investment Trust Inc stock charts, 140910 price quote, 140910 quote, A Self-Administered Real Estate Investment Trust Inc news, 140910, 140910 stock, 140910 stock price, 140910 stock charts, stock, stock price, stock charts" name="keywords"/>
# <link href="https://assets.bwbx.io/s3/bbgmkts/images/favicon-black.png" rel="shortcut icon" type="image/png"/>
# <meta content="Bloomberg.com" property="og:site_name"/>
# <meta content="140910:Korea SE Stock Quote - A Self-Administered Real Estate Investment Trust Inc" property="og:title"/>
# <meta content="Stock analysis for A Self-Administered Real Estate Investment Trust Inc (140910:Korea SE) including stock price, stock chart, company news, key statistics, fundamentals and company profile." property="og:description"/>
# <meta content="/images/markets-logo.png" property="og:image"/>
# <meta content="company" property="og:type"/>
# <meta content="https://www.bloomberg.com/quote/140910:KS" property="og:url"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="Stock analysis for A Self-Administered Real Estate Investment Trust Inc (140910:Korea SE) including stock price, stock chart, company news, key statistics, fundamentals and company profile." name="twitter:description"/>
# <meta content="140910:Korea SE Stock Quote - A Self-Administered Real Estate Investment Trust Inc" name="twitter:title"/>
# <meta content="https://www.bloomberg.com/quote/140910:KS" name="twitter:url"/>
# <meta content="@markets" name="twitter:creator"/>
# <meta content="@markets" name="twitter:site"/>
# <link href="https://www.bloomberg.com/quote/140910:KS" rel="canonical"/>
# <link href="https://assets.bwbx.io/s3/bbgmkts/assets/normalize-bb22b1681acf23ebc5cab8fadea393a7.css" rel="stylesheet" type="text/css"/>
# <link href="https://assets.bwbx.io/s3/bbgmkts/assets/quote-5fd71e40cbcd424004f9d1bdb6ab3b6e.css" rel="stylesheet" type="text/css"/>
# <link href="https://assets.bwbx.io/font-service/css/AvenirNextPForBBG-Demi%2CBloomberg%2CBWHaasGrotesk-65Medium-Web%2CBW%20Haas%20Text%20Mono%20A-55%20Roman%2CBloomberg%20Logotypes-Medium%2CBWHaasGrotesk-55Roman-Web%2CBWHaasGrotesk-75Bold-Web%2CBWHaasGrotesk-95Black-Web%2CBWHaasGroteskTF-55Roman-Web/font-face.css" rel="stylesheet" type="text/css"/>
# <link href="https://assets.bwbx.io/font-service/css/AvenirNextPForBBG:400,600/styled-font-face.css" rel="stylesheet" type="text/css"/><link href="https://www.bbthat.com/assets/v2.2.2/that.css" rel="stylesheet" type="text/css"/>
# <link href="https://assets.bwbx.io/font-service/css/Bloomberg%20Logotypes-Medium,BWHaasGrotesk-75Bold-Web,BWHaasGrotesk-95Black-Web,BWHaasGrotesk-55Roman-Web/font-face.css" rel="stylesheet"/><link href="https://assets.bwbx.io/s3/navi/css/components/bar/bar-f7c137090e.css" rel="stylesheet"/><link href="https://assets.bwbx.io/s3/navi/vendor/css/reg-ui-client-162e0da6e2.css" rel="stylesheet"/><noscript>&lt;style&gt;.noscript-hide{display:none;}.navi-bar__button--subscribe{margin-right:20px;}&lt;/style&gt;</noscript><script>!function(){if(!(Math.random()&gt;.035||window.BOOMR&amp;&amp;window.BOOMR.version)){var e,t,n,o=document.createElement("iframe"),a=window;a.addEventListener?a.addEventListener("load",i,!1):a.attachEvent&amp;&amp;a.attachEvent("onload",i),o.src="javascript:void(0)",o.title="",o.role="presentation",(o.frameElement||o).style.cssText="width:0;height:0;border:0;display:none;",(n=document.getElementsByTagName("script")[0]).parentNode.insertBefore(o,n);try{t=o.contentWindow.document}catch(n){e=document.domain,o.src="javascript:var d=document.open();d.domain='"+e+"';void(0);",t=o.contentWindow.document}t.open()._l=function(){var t=this.createElement("script");e&amp;&amp;(this.domain=e),t.id="boomr-if-as",t.src="https://s.go-mpulse.net/boomerang/T6PPY-X9KZV-8VZ6F-7N5GB-F8ELN",BOOMR_lstart=(new Date).getTime(),this.body.appendChild(t)},t.write('&lt;body onload="document._l();"&gt;'),t.close()}function i(e){a.BOOMR_onload=e&amp;&amp;e.timeStamp||(new Date).getTime()}}();</script>
# <link href="https://assets.bwbx.io/font-service/css/Bloomberg/font-face.css" rel="stylesheet" type="text/css"/><link href="https://assets.bwbx.io/s3/bbnav/public/stylesheets/bb-global-footer-7fce47d03a.css" rel="stylesheet" type="text/css"/>
# <script src="https://assets.bwbx.io/s3/bbgmkts/assets/geoip-b10d6156409a770b2979.js" type="text/javascript"></script>
# <script src="https://assets.bwbx.io/s3/bbgmkts/assets/personalization-a1caa3def3a926a4af0f.js" type="text/javascript"></script>
# <script type="text/javascript">
#             window._taboola = window._taboola || [];
#             _taboola.push({category:'auto'});
#             !function (e, f, u, i) {
#             if (!document.getElementById(i)){
#             e.async = 1;
#             e.src = u;
#             e.id = i;
#             f.parentNode.insertBefore(e, f);
#         }
#         }(
#             document.createElement('script'),
#             document.getElementsByTagName('script')[0],
#             '//cdn.taboola.com/libtrc/bloomberg/loader.js',
#             'tb_loader_script'
#             );
#             if(window.performance &amp;&amp; typeof window.performance.mark === 'function'){
#             window.performance.mark('tbl_ic');
#         }
#         </script>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <script type="text/javascript">
#             (function(w) {
#                 w.dataLayer = w.dataLayer || [];
#                 w.dataLayer.push({"adcode":"markets/quote","brand":"markets","contentType":"marketdata-quote-common_stock","pageType":"marketdata","template":"shichang-marketdata-html"});
#             })(window);
#         </script>
# <!-- Google Tag Manager --><script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&amp;l='+l:'';j.defer=true;j.src='https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-MNTH5N');</script><!-- End Google Tag Manager -->
# <script type="text/javascript">window.tradeitPub = "bloomberg";</script><link href="//assets.bwbx.io" rel="dns-prefetch"/><link href="//assets.bwbx.io/s3/fence/v4/styles.css" rel="stylesheet"/><link href="https://assets.bwbx.io/font-service/css/BWHaasGrotesk-55Roman-Web,BWHaasGrotesk-75Bold-Web,Bloomberg/font-face.css" rel="stylesheet"/><style data-from="pianola" type="text/css">
#         .tp-modal {
#             z-index: 6000003 !important;
#         }
#
#         .tp-backdrop.tp-active {
#             z-index: 6000001 !important;
#         }
#     </style><script data-exclude="true" src="https://s3.amazonaws.com/bvp-staging/projector/latest/bplayer.js" type="text/javascript"></script><script src="https://www.googleadservices.com/pagead/conversion/1063184170/?random=1554848135499&amp;cv=9&amp;fst=1554848135499&amp;num=1&amp;value=0&amp;label=6VpQCOnp7YkBEKrO-_oD&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;u_h=800&amp;u_w=1280&amp;u_ah=704&amp;u_aw=1280&amp;u_cd=24&amp;u_his=7&amp;u_tz=-240&amp;u_java=false&amp;u_nplug=3&amp;u_nmime=4&amp;gtm=2wg430&amp;sendb=1&amp;frm=0&amp;url=https%3A%2F%2Fwww.bloomberg.com%2Fquote%2F140910%3AKS&amp;tiba=140910%3AKorea%20SE%20Stock%20Quote%20-%20A%20Self-Administered%20Real%20Estate%20Investment%20Trust%20Inc%20-%20Bloomberg%20Markets&amp;bttype=purchase&amp;async=1&amp;rfmt=3&amp;fmt=4"></script><script src="https://www.googleadservices.com/pagead/conversion/759744127/?random=1554848135500&amp;cv=9&amp;fst=1554848135500&amp;num=1&amp;value=0&amp;label=NPt6CL6b_JYBEP-Mo-oC&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;u_h=800&amp;u_w=1280&amp;u_ah=704&amp;u_aw=1280&amp;u_cd=24&amp;u_his=7&amp;u_tz=-240&amp;u_java=false&amp;u_nplug=3&amp;u_nmime=4&amp;gtm=2wg430&amp;sendb=1&amp;frm=0&amp;url=https%3A%2F%2Fwww.bloomberg.com%2Fquote%2F140910%3AKS&amp;tiba=140910%3AKorea%20SE%20Stock%20Quote%20-%20A%20Self-Administered%20Real%20Estate%20Investment%20Trust%20Inc%20-%20Bloomberg%20Markets&amp;bttype=purchase&amp;async=1&amp;rfmt=3&amp;fmt=4"></script><script src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/1063184170/?random=1554848135502&amp;cv=9&amp;fst=1554848135502&amp;num=1&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;u_h=800&amp;u_w=1280&amp;u_ah=704&amp;u_aw=1280&amp;u_cd=24&amp;u_his=7&amp;u_tz=-240&amp;u_java=false&amp;u_nplug=3&amp;u_nmime=4&amp;gtm=2wg430&amp;sendb=1&amp;frm=0&amp;url=https%3A%2F%2Fwww.bloomberg.com%2Fquote%2F140910%3AKS&amp;tiba=140910%3AKorea%20SE%20Stock%20Quote%20-%20A%20Self-Administered%20Real%20Estate%20Investment%20Trust%20Inc%20-%20Bloomberg%20Markets&amp;async=1&amp;rfmt=3&amp;fmt=4"></script><script src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/759744127/?random=1554848135503&amp;cv=9&amp;fst=1554848135503&amp;num=1&amp;guid=ON&amp;resp=GooglemKTybQhCsO&amp;u_h=800&amp;u_w=1280&amp;u_ah=704&amp;u_aw=1280&amp;u_cd=24&amp;u_his=7&amp;u_tz=-240&amp;u_java=false&amp;u_nplug=3&amp;u_nmime=4&amp;gtm=2wg430&amp;sendb=1&amp;frm=0&amp;url=https%3A%2F%2Fwww.bloomberg.com%2Fquote%2F140910%3AKS&amp;tiba=140910%3AKorea%20SE%20Stock%20Quote%20-%20A%20Self-Administered%20Real%20Estate%20Investment%20Trust%20Inc%20-%20Bloomberg%20Markets&amp;async=1&amp;rfmt=3&amp;fmt=4"></script><script async="" charset="utf-8" src="https://assets.bwbx.io/s3/navi/js/breaking-news-app-ff5a6b56c9ed2911c087.js" type="text/javascript"></script><script async="" src="https://a2.adform.net/Serving/TrackPoint/?pm=1118168&amp;ADFdivider=%7C&amp;ord=414730035830&amp;Set1=en-US%7Cen-US%7C1280x800%7C24&amp;ADFtpmode=2&amp;loc=https%3A%2F%2Fwww.bloomberg.com%2Fquote%2F140910%3AKS"></script><a aria-hidden="true" href="/quote/140910:KS?_pxhc=1554848135562" rel="nofollow" style="width: 0px; height: 0px; font-size: 0px; line-height: 0;" tabindex="-1" target="_blank"></a><style type="text/css">/*---------------------------------------------------------------------------------------
#     Backdrop
# ---------------------------------------------------------------------------------------*/
#
# .tp-backdrop {
#     display: none;
#     position: fixed;
#     top: 0px;
#     left: 0px;
#     right: 0px;
#     bottom: 0px;
#     background: #121214;
#     z-index: 300000;
#     opacity: 0;
#     -webkit-transition: opacity .25s linear;
#     -moz-transition: opacity .25s linear;
#     -ms-transition: opacity .25s linear;
#     -o-transition: opacity .25s linear;
#     transition: opacity .25s linear;
# }
#
# .tp-backdrop.tp-active {
#     opacity: .9;
# }
#
# /*---------------------------------------------------------------------------------------
#     Modal container close button
# ---------------------------------------------------------------------------------------*/
#
# .tp-modal .tp-close.tp-square {
#     /*background: #578fe0;*/
#     background: #ccc;
#     border-radius: 0;
#     border: 0;
#     top: 0;
#     right: -40px;
# }
#
#
# .tp-modal .tp-close {
#     line-height: 37px;
#     display: none;
#     position: absolute;
#     top: -20px;
#     right: -20px;
#     width: 40px;
#     height: 40px;
#     /*background: transparent url("libs/img/close.png") no-repeat;*/
#     background: #ccc;
#     border: 2px solid #fff;
#     z-index: 300100;
#     border-radius: 40px;
#     opacity: 0;
#     cursor: pointer;
#     color: #fff;
#     font-family: Arial, sans-serif;
#     font-size: 22px;
#     text-align: center;
#     transform: scale(.25, .25);
#     -moz-transform: scale(.25, .25);
#     -ms-transform: scale(.25, .25);
#     -webkit-transform: scale(.25, .25);
#     -o-transform: scale(.25, .25);
#     /*-webkit-transition: all .4s ease-in-out;*/
#     /*-moz-transition: all .4s ease-in-out;*/
#     /*-ms-transition: all .4s ease-in-out;*/
#     /*-o-transition: all .4s ease-in-out;*/
#     /*transition: all .4s ease-in-out;*/
# }
#
# .tp-modal .tp-close.tp-active {
#     display: block;
#     opacity: 1;
#     transform: scale(1.0, 1.0);
#     -moz-transform: scale(1.0, 1.0);
#     -ms-transform: scale(1.0, 1.0);
#     -webkit-transform: scale(1.0, 1.0);
#     -o-transform: scale(1.0, 1.0);
# }
#
# .tp-modal {
#     z-index: 300050;
# }
#
# @media screen and (max-width: 650px) {
#     .tp-modal .tp-close {
#         right: 0;
#     }
# }
#
#
# /*---------------------------------------------------------------------------------------
#     Modal
# ---------------------------------------------------------------------------------------*/
# .tp-modal .tp-iframe-wrapper.tp-curtain {
#     width: 600px;
#     height: 480px;
# }
#
# .body-fixed {
#     position: fixed;
# }
#
# .tp-modal-open {
#     overflow: hidden!important;
#     -webkit-overflow-scrolling: touch;
# }
# .tp-modal-open.tp-modal-resizing {
#     -webkit-overflow-scrolling: auto;
# }
#
# /* fix for iOS input elements bug */
# .tp-modal-experiment.body-fixed {
#     position: initial;
# }
# .tp-modal-experiment.tp-modal-open &gt; * {
#     display: none;
# }
# .tp-modal-experiment .tp-modal {
#     position: relative;
# }
#
# /*Bug fix of firefox v57*/
# .tp-modal-close {
#     overflow: auto;
# }
#
# .tp-iframe-wrapper {
#     position: relative;
#     margin: 40px auto;
#     box-shadow: 0 0 10px rgba(0, 0, 0, 0.21);
# }
# .tp-modal {
#     overflow-x: hidden;
#     overflow-y: scroll;
#     display: none;
#     position: fixed;
#     top: 0;
#     bottom: 0;
#     left: 0;
#     right: 0;
# }
# .tp-modal .tp-iframe-wrapper.tp-active {
#     transform: scale(1.0, 1.0);
#     -moz-transform: scale(1.0, 1.0);
#     -ms-transform: scale(1.0, 1.0);
#     -webkit-transform: scale(1.0, 1.0);
#     -o-transform: scale(1.0, 1.0);
# }
#
# .tp-modal .tp-message {
#     font-family: "Graphik Web Regular", Helvetica, Arial, sans-serif;
#     padding: 10px;
# }
#
# .tp-modal .tp-btn-container {
#     padding-left: 10px;
#     padding-bottom: 10px;
# }
#
# .tp-btn {
#     text-decoration: none;
#     cursor: pointer;
#     padding: 0px 18px;
#     line-height: 40px;
#     border-collapse: separate;
#     border-radius: 4px;
#     text-align: center;
#     vertical-align: middle;
#     text-decoration: none;
#     display: inline-block;
#     color: #fff;
#     border: none;
#     box-shadow: inset 0px -1px 0px rgba(216, 218, 221, 0.0);
#     background: #3878D8;
#     background-position: bottom;
#     text-shadow: none;
#     font-family: "Graphik Web Regular", Helvetica, Arial, sans-serif;
#     white-space: nowrap;
#     outline: 0;
# }
#
# .tp-please-wait.tp-active {
#     display: block;
#     opacity: .9;
#     -webkit-transition: opacity .25s linear;
#     -moz-transition: opacity .25s linear;
#     -ms-transition: opacity .25s linear;
#     -o-transition: opacity .25s linear;
#     transition: opacity .25s linear;
# }
#
# .tp-please-wait {
#     position: absolute;
#     top: 0;
#     left: 0;
#     background-color: #999;
#     opacity: 0;
#     width: 100%;
#     height: 100%;
#     display: none;
#     text-align: center;
#     color: #fff;
#     font-weight: lighter;
#     font-family: "Open Sans", sans-serif;
#     font-size: 15px;
# }
#
# .tp-please-wait &gt; .tp-icon {
#     width: 46px;
#     height: 46px;
#     background-image: url('data:image/gif;base64,...');
#     margin: 100px auto 20px auto;
# }
#
# /*---------------------------------------------------------------------------------------
#     Close Button
# ---------------------------------------------------------------------------------------*/
#
# .tp-iframe-wrapper.no-width .tp-close,
# .tp-iframe-wrapper.no-height .tp-close,
# .tp-modal.no-width .tp-close,
# .tp-modal.no-height .tp-close {
#     display: none;
# }</style><script async="" src="//widget.perfectmarket.com/bloomberg/pmk-201808001.202.js" type="text/javascript"></script><link as="script" href="https://adservice.google.com/adsid/integrator.js?domain=www.bloomberg.com" rel="preload"/><script src="https://adservice.google.com/adsid/integrator.js?domain=www.bloomberg.com" type="text/javascript"></script><script async="" src="https://securepubads.g.doubleclick.net/gpt/pubads_impl_2019032901.js"></script><style type="text/css">.trc_rbox_container{direction:ltr;text-align:left}.trc_multi_widget_container{display:-ms-flexbox;display:flex;-ms-flex-pack:justify;justify-content:space-between}.trc_multi_widget_container .trc_rbox_div{margin:0}.trc_rbox_header{border:0 solid;overflow:hidden;vertical-align:middle}.trc_rbox_container .trc_img{display:inline-block!important}.trc_rbox_header_icon_div{display:table-cell;vertical-align:baseline}.trc_rbox_header .trc_rbox_header_icon_div .trc_rbox_header_icon_img{vertical-align:middle;width:auto}.trc_rbox_header_icon_span{display:inline-table}.in_trc_header{position:relative!important;float:right;margin:0}#trc_rbox_css_loaded{overflow:hidden;width:0;height:0}.trc_rbox{margin-top:0}.trc_rbox_div{margin:0 0 3px;direction:ltr;padding:0;box-sizing:border-box;-moz-box-sizing:border-box;-ms-box-sizing:border-box;-webkit-box-sizing:border-box;overflow:auto;position:relative;width:auto;border:solid #ccc 1px}.loading-animation span{display:block}.videoCube{zoom:1;cursor:pointer;float:none;overflow:hidden;box-sizing:border-box;-moz-box-sizing:border-box;-ms-box-sizing:border-box;-webkit-box-sizing:border-box}.videoCube_hover,div.videoCube:hover{cursor:pointer}.videoCube span.video-title:hover,.videoCube_hover span.video-title{text-decoration:underline}.videoCube a{text-decoration:none;border:0;color:#000;cursor:pointer}.videoCube a,.videoCube a:hover,.videoCube a:link,.videoCube_hover a{text-decoration:none!important;outline:0}.videoCube a .thumbBlock{float:left;display:block;overflow:hidden!important}.videoCube a img,.videoCube img{border:0;display:block;margin:0;height:auto;width:auto}.videoCube .video-label{display:block;overflow:hidden}.videoCube .video-label{width:auto!important;white-space:pre-wrap;white-space:-moz-pre-wrap;white-space:-o-pre-wrap;word-wrap:break-word}.videoCube .video-label-box.label-box-with-title-icon{display:table}.video-icon-container{float:left;display:table-cell;vertical-align:baseline}.video-icon-img{vertical-align:middle}.videoCube .video-duration{height:0;float:left;position:relative;color:#fff;font-size:11px}.videoCube .video-duration dt{border-radius:4px;-moz-border-radius:4px;-webkit-border-radius:4px;background-color:#000;opacity:.6}.videoCube span.video-label.trc_ellipsis{position:relative;overflow:hidden;display:-webkit-box;-webkit-box-orient:vertical}.videoCube span.video-label.trc-smart-ellipsis{position:relative;overflow:hidden}.videoCube span.video-label.trc-smart-ellipsis ins{display:inline-block;text-decoration:inherit}.videoCube span.video-label.trc-smart-ellipsis ins.lastLineEllipsis{display:block;overflow:hidden;text-overflow:ellipsis;white-space:nowrap;word-wrap:normal}.video-duration.video-duration-detail div{color:#fff}.trc_rbox .sponsored{position:relative;display:block;overflow:visible;height:auto;width:auto;padding-right:0;text-align:right;font-size:9px}.trc_rbox_div{height:410px}.videoCube{direction:ltr;font-size:11px;margin:0;color:#000;border-width:0}.videoCube.vertical:first-child{border-top:0;margin-top:0}.videoCube.horizontal:first-child{border-left:0;margin-left:0}.videoCube_hover,div.videoCube:hover{background-color:#ebf0ff;color:#000}.videoCube .thumbBlock{margin-right:5px;margin-left:1px;border-style:solid}.videoCube a img,.videoCube img{border-color:#ececec}.videoCube .video-label-box{margin-left:81px}.videoCube .video-label dt{font-weight:700}.videoCube .video-title{height:auto;margin-bottom:3px;white-space:normal}.videoCube .trc_inline_detail_spacer{display:inline-block;white-space:pre} ...
#  text-decoration: none !important;
# }
# .trc_rbox_div {
#     margin: 0;
# }
#
# /*.trc_rbox .trc_rbox_header {
#     padding: 5px;
# }*/
#
# .trc_rbox .sponsored-default .video-description {
#         display: none;
# }
#
# DIV.trc_related_container .trc_rbox .trc_rbox_div .video_group {
#         padding: 0;
#         max-height: auto!important;
# }
#
# .trc_rbox .videoCube .thumbnail-overlay {
#     position: absolute!important;
#     /*margin-left: -137px;*/
# }
# .trc_rbox .videoCube .thumbnail-overlay .overlay {
#     background-color: black;
#     opacity: 0.5;
#     padding: 5px;
#     position: absolute;
#     width: 127px;
#     /*filter: alpha(opacity=0.5);*/
# }
# .trc_rbox .videoCube .thumbnail-overlay .play_video_link {
#     position: absolute;
#     width: 137px;
# }
# .trc_rbox .videoCube .thumbnail-overlay .play_video_link a {
# background-image: url(http://www.bloomberg.com/images/icons/icon_video_17x13.png);
# background-repeat: no-repeat;
# color: white;
# display: block;
# font-family: Arial, Helvetica, sans-serif;
# font-weight: bold;
# background-position: 5px 81px;
# padding: 79px 0px 5px 27px;
# }
# .trc_rbox .videoCube .thumbBlock img {
#     float: none;
#     padding-left: 0!important;
#     padding-right: 0!important;
# }
# .trc_rbox .sponsored-default .thumbBlock {
#         border: solid 1px #dddddd;
#         width: 137px!important;
#         *height: 81px!important;
#         padding-top: 16px;
#         box-sizing: border-box;
#         -webkit-box-sizing: border-box;
#         -moz-box-sizing: border-box;
#         background-color: white;
# }
# .trc_rbox .sponsored-default .thumbBlock img {
#     width: auto !important;
#     height: 81px !important;
# }
# .trc_rbox .sponsored {
#     text-align: center;
#     width: 137px;
#     top: auto;
#     _top: auto;
#     *margin-left: -142px;
#     position: absolute;
#     margin-top: 0;
# }
#
# .sponsored-url {
#     font-weight:normal;
#     float:none;
#     text-decoration:none;
#     display: block;
#     width: auto;
# }
#
# .trc_rbox_div .videoCube{
#         padding-right:0px !important;
#         padding-left: 0px !important;
# }
#
# .trc_rbox_div .videoCube {
#     /* *height: 99px;*/
# }
#
# .taboola_horizontal_bb_video .trc_rbox_div .videoCube{
# padding:7px 6px 8px;
# }
#
# .autosized-1h .trc_rbox_div .videoCube{
# 	padding-right:0px !important;
# 	padding-left: 0px !important;
# }
#
# .autosized-1h-sc .trc_rbox_div .videoCube{
#         padding-right:0px !important;
#         padding-left: 0px !important;
# }
#
# .grid-2x2-video .trc_rbox_div .videoCube{
#         padding-right:0px !important;
#         padding-left: 0px !important;
# }
#
# .loading-animation {
# font-size:12px;
# font-family:Verdana;
# color:#000000;
# margin-top:10px;
# margin-left:10px;
# border:none;
# text-align:left;
# font-weight:normal;
# }
#
# DIV.videoCube {
#     cursor: default!important;
# }
# DIV.videoCube a {
#     cursor: pointer;
# }
# .videoCube .play_video_link a {
#         color: white;
# }
#
# .videoCube a .video-label-box {
#     /* height: 85px; */
#     height: auto;
# }
#
# .videoCube.sponsored-default a .video-label-box {
#     height: 85px;
# }
#
# /*
# .trc_rbox.rbox-t2v {
#         width: 628px;
# }
#
# .rbox-t2v .trc_rbox_div {
#     padding: 0 6px;
# }
#
# .rbox-t2v .videoCube {
#     padding: 10px 8px 0;
# }
#
# .rbox-t2v .videoCube a .thumbBlock {
#     float: none;
# }
# .rbox-t2v .videoCube a .thumbBlock img {
#         float: none;
# }
# .rbox-t2v .videoCube a .video-label-box {
#     margin: 0;
# }
#
# .trc_rbox.rbox-t2v .videoCube .thumbnail-overlay {
#     margin-left: 0;
# }
#
# .trc_rbox.rbox-t2v .trc_pager_wrapper {
#         position: absolute;
#         width: 628px;
# }
# .trc_rbox .trc_pager {
#     margin-top: -176px;
#     display: block;
#     right: 8px;
#     font-size: 11px!important;
# }
#
# .trc_rbox .trc_pager_pages { display: none!important; }
# .trc_rbox .trc_pager_counter {
#     display: block!important;
#     color: #d1d1d1;
# }
# .trc_rbox .pager_enabled {
#     color: white;
#     font-weight: bold;
#     margin-top: 2px!important;
# }
# .trc_rbox .pager_disabled {
#     color: transparent;
# }
# */
# .rbox-t2v .trc_pager_counter {
#     color: #d1d1d1;
# }
# .rbox-t2v .pager_enabled {
#     color: white;
#     font-weight: bold;
# }
# .rbox-t2v .pager_disabled  {
# display:none;
# }
# .rbox-t2v .trc_pager_prev:hover, .rbox-t2v .trc_pager_next:hover{
# color:white;
# }
#
#
#
# /* Hide R-Box on market pages until it is loaded */
#
# /* AB tested R-Box t2v horizontal */
# .taboola_horizontal_bb_video .trc_rbox .trc_rbox_div { height: 155px; width: auto; }
# .taboola_horizontal_bb_video .trc_rbox .videoCube { height: 155px; margin:0 4px; _margin: 0 4px; *width: 140px;}
# .taboola_horizontal_bb_video .trc_rbox .videoCube .video-label-box { margin-top: 2px; margin-left: 0; }
# .taboola_horizontal_bb_video .trc_rbox .sponsored { top: 8px; }
# .taboola_horizontal_bb_video .trc_rbox .pager_enabled, .taboola_horizontal_bb_video .trc_rbox .pager_disabled { font-weight: bold; }
# .taboola_horizontal_bb_video .trc_rbox .videoCube.sponsored-default a .video-label-box { height: auto; }
# .taboola_horizontal_bb_video .trc_rbox .sponsored-url { text-decoration: none; }
# .taboola_horizontal_bb_video .trc_rbox .videoCube .video-title { *height: 2.58em; }
# .taboola_horizontal_bb_video .trc_rbox .sponsored-default .video-title { max-height: 2.58em; margin-bottom:0px!important;}
# .taboola_horizontal_bb_video .trc_rbox .videoCube.sponsored-default a .video-label-box { height: auto; }
# .taboola_horizontal_bb_video .trc_rbox .sponsored { *margin-left: 0; }
# .trc_pager div { font-family: Arial, Helvetica, sans; }
#
# .trc_rbox .videoCube a{color:#0033CC;}
#
#
# .taboola_horizontal_bb_video .trc_rbox.had_v2 .videoCube { margin: 0 5px; _margin: 0 4px; }
# .taboola_horizontal_bb_video .trc_rbox.had_v2 .gam_container { border-left: dotted #CCC 1px !important; padding:7px 12px 0 11px;}
# .taboola_horizontal_bb_video .trc_rbox.had_v2 .logoDiv { padding-right: 12px; }
# .taboola_horizontal_bb_video .trc_rbox.had_v2 .trc_pager.in_trc_header { margin-right: 12px; }
# .trc_rbox.vad_v2 .gam_container { border-top: dotted #666 1px; padding-top: 4px; margin: 5px 6px 0;}
# .trc_rbox.mad_v2 .gam_container { border-top: dotted #666 1px; padding-top: 4px; margin: 5px 6px 0;}
#
# .rbox-t2v .sponsored-default, .rbox-blended .sponsored-default, .R-Box_Market_Pages .sponsored-default, .ab_rbox-blended_google-v2 .sponsored-default, .ab_rbox-t2v_google-v2 .sponsored-default{padding-bottom:8px!important;}
#
# /**NEW MODES SUPPORT**/
# .taboola_horizontal_bb_video .trc_rbox.new_had_v2 .videoCube { margin: 0; }
# .taboola_horizontal_bb_video .trc_rbox.ab_horizontal-t2v_recs5 .videoCube { margin: 0 4px; }
# .taboola_horizontal_bb_video .trc_rbox.new_had_v2 .gam_container {border-left: 1px dotted #CCCCCC !important; padding: 7px 12px 0 11px;}
# .taboola_horizontal_bb_video .trc_rbox.new_had_v2 .videoCube .thumbnail-overlay .overlay { width: 96px; }
# .taboola_horizontal_bb_video .trc_rbox.new_had_v2 .videoCube .thumbnail-overlay .play_video_link { width: 106px; }
# .videoCube .thumbBlock {
#    margin:0px!important;
# }
#
# .taboola_horizontal_bb_video .trc_rbox.new_had_v2 .trc_pager.in_trc_header {
#     margin-right: 8px;
# }
# .taboola_horizontal_bb_video .trc_rbox.new_had_v2 .logoDiv {
#     padding-right: 8px;
# }
# .ab_horizontal-t2v_recs4-g .trc_rbox_div,.ab_horizontal-narrow-t2v_google-v2 .trc_rbox_div{padding-left:4px;}
# .videoCube.vertical .sponsored-url {
#     padding-left: 7px;
# }
#
#
#
#
# /* override bootstrap default span definitions */
# .ab_texts-links-2c_abp-sc [class*=span] {
#     float:none;
#     margin-left:0px;
# }
#
# .ab_texts-links-2c_abp-sc .trc_rbox_header {
#         line-height: 1.2em;
#         position: relative;
#         display: inline-block;
#         width: 100%;
# 	height: auto;
# }
#
# .ab_texts-links-2c_abp-sc .trc_rbox_header_span .trc_header_right_column {
#         position: absolute;
#         width: 48%;
#         left: 52%;
#         top: 0;
# 	background: transparent;
# 	height: auto;
# }
#
# .ab_texts-links-2c_abp-sc .trc_rbox_header .logoDiv {
#         font-size: inherit;
#         line-height: normal;
#         position: relative;
#         z-index: 1;
# }
#
# .ab_texts-links-2c_abp-sc .logoDiv a {
#     font-size: 100%;;
# }
#
#
# .ab_texts-links-2c_abp-sc .logoDiv a span {
#     color: black;
#     font-weight: normal;
#     font-size: 10px;
# }
#
# .ab_texts-links-2c_abp-sc .syndicatedItem .video-title .branding {
#         line-height: 1.3em;
# }
#
# .ab_texts-links-2c_abp-sc .trc_rbox_div .videoCube.horizontal {
#         clear: left;
# }
#
# .ab_texts-links-2c_abp-sc .trc_rbox_div .videoCube.trc_tl_right_col {
#         float: none;
#         margin-left: auto;
# }
#
# .ab_texts-links-2c_abp-sc .videoCube:hover span.branding,
# .ab_texts-links-2c_abp-sc .videoCube_hover span.branding {
#         text-decoration: none;
# }
#
# .ab_texts-links-2c_abp-sc .trc_rbox_div .videoCube.thumbnail_none a{
#     display: list-item;
#     list-style: disc outside none;
#     vertical-align: top;
#     overflow: visible;
#     margin-left: 20px;
#     padding: 0;
# }
#
# .ab_texts-links-2c_abp-sc .videoCube .video-label-box {
#         display: inline-block!important;
#         vertical-align: top;
#         width: 100%;
#         *margin-top: -3px;
# 	min-height: 22.0px;
# }
#
# .ab_texts-links-2c_abp-sc .trc_rbox_div .videoCube:hover .video-title {
#         text-decoration: underline;
# }
# .ab_texts-links-2c_abp-sc .trc_header_left_column {
# 	width: 100%;
# 	display: inline-block;
# 	background: transparent;
# 	height: auto;
# }
#
# .ab_texts-links-2c_abp-sc .trc_rbox_header .logoDiv a {
# 	font-size: 100%;
# }
#
# .ab_texts-links-2c_abp-sc .syndicatedItem .branding {
# 	line-height: 22.0px;
# }
#
# .ab_texts-links-2c_abp-sc .trc_rbox_header .trc_header_ext {
# 	position: relative;
# 	top: auto;
# 	right: auto;
# }
#
# .ab_thumbnails-d_abp-sc img {
#         max-width: none;
# }
#
# /* override bootstrap default span definitions */
# .ab_thumbnails-d_abp-sc [class*=span] {
#     float:none;
#     margin-left:0px;
# }
#
#
# .ab_thumbnails-d_abp-sc .trc_rbox_header {
#     position: relative;
#     display: inline-block;
#     width: 100%;
# 	background: transparent;
# 	height: 37px;
# 	Line-height: 34px;
# }
#
# .ab_thumbnails-d_abp-sc .trc_rbox_header .trc_rbox_header_span {
# 	position: relative;
# }
# .ab_thumbnails-d_abp-sc .trc_rbox_header_span .trc_header_right_column {
#         display: none;
# 	background: transparent;
# 	height: auto;
# }
#
# .ab_thumbnails-d_abp-sc .trc_rbox_header .logoDiv {
#         font-size: inherit;
#         line-height: normal;
# }
#
# .ab_thumbnails-d_abp-sc .logoDiv a {
#     font-size: 100%;
# }
#
# .ab_thumbnails-d_abp-sc .logoDiv a span {
#     display: inline;
#     color: #000;
#     font-weight: normal;
#     font-size: 11.0px;
# }
#
# .ab_thumbnails-d_abp-sc .videoCube a {
#     padding: 0;
# }
#
# .ab_thumbnails-d_abp-sc .thumbBlock {
#     margin: 0;
# }
#
# .trc_elastic .ab_thumbnails-d_abp-sc .video-label-box {
#     height: 66.0px;
# }
#
# .ab_thumbnails-d_abp-sc .videoCube .video-label-box {
#     padding: 0 5px;
#     border-color: #E4E4E4;
#     border-style: solid;
# 	border-width: 0 0 0 2px;
# }
#
# .ab_thumbnails-d_abp-sc .videoCube .video-label-box .video-title {
#     text-decoration: none;
#     margin: 0;
# }
#
# .ab_thumbnails-d_abp-sc .videoCube:hover .video-label-box .video-title {
#     text-decoration: underline;
# }
#
# .ab_thumbnails-d_abp-sc .video-label-box .branding {
#     display: block;
# }
#
# .ab_thumbnails-d_abp-sc .syndicatedItem .branding {
#     line-height: 12.0px;
#     height : 18.0px;
# }
# .ab_thumbnails-d_abp-sc .trc_header_left_column {
# 	width: 48%;
# 	display: inline-block;
# 	background: transparent;
# 	height: auto;
# }
#
# .ab_thumbnails-d_abp-sc .trc_rbox_header .logoDiv a {
# 	font-size: 100%;
# }
#
# .ab_thumbnails-d_abp-sc .trc_rbox_header .trc_header_ext {
# 	position: relative;
# 	top: auto;
# 	right: auto;
# }
# .ab_thumbs-2r_abp-sc img {
#         max-width: none;
# }
#
# /* override bootstrap default span definitions */
# .ab_thumbs-2r_abp-sc [class*=span] {
#     float:none;
#     margin-left:0px;
# }
#
#
# .ab_thumbs-2r_abp-sc .trc_rbox_header {
#         line-height: 1.2em;
#         position: relative;
#         display: inline-block;
#         width: 100%;
# 	background: transparent;
# 	height: auto;
# }
#
# .ab_thumbs-2r_abp-sc .trc_rbox_header_span .trc_header_right_column {
#         display: none;
# 	background: transparent;
# 	height: auto;
# }
#
# .ab_thumbs-2r_abp-sc .trc_rbox_header .logoDiv {
#         font-size: inherit;
#         line-height: normal;
# }
#
# .ab_thumbs-2r_abp-sc .logoDiv a {
#     font-size: 100%;
# }
#
# .ab_thumbs-2r_abp-sc .logoDiv a span {
#     display: inline;
#     color: #000000;
#     font-weight: normal;
#     font-size: 13.6px;
# }
#
# .ab_thumbs-2r_abp-sc .videoCube a {
#     padding: 0;
# }
#
# .ab_thumbs-2r_abp-sc .thumbBlock {
#     margin: 0;
# }
#
# .trc_elastic .ab_thumbs-2r_abp-sc .video-label-box {
#     height: 66.0px;
# }
#
# .ab_thumbs-2r_abp-sc .videoCube .video-label-box {
#     margin-top: 5px;
# }
#
# .ab_thumbs-2r_abp-sc .videoCube .video-label-box .video-title {
#     text-decoration: none;
#     margin: 0;
# }
#
# .ab_thumbs-2r_abp-sc .videoCube:hover .video-label-box .video-title {
#     text-decoration: underline;
# }
#
# .ab_thumbs-2r_abp-sc .video-label-box .branding {
#     display: block;
# }
#
# .ab_thumbs-2r_abp-sc .syndicatedItem .branding {
#     line-height: 22.0px;
# }
# .ab_thumbs-2r_abp-sc .trc_header_left_column {
# 	width: 48%;
# 	display: inline-block;
# 	background: transparent;
# 	height: auto;
# }
#
# .ab_thumbs-2r_abp-sc .trc_rbox_header .logoDiv a {
# 	font-size: 100%;
# }
#
# .ab_thumbs-2r_abp-sc .trc_rbox_header .trc_header_ext {
# 	position: relative;
# 	top: auto;
# 	right: auto;
# }
# .exchange-thumbs-feed-01 img {
#         max-width: none;
# }
# /* override bootstrap default span definitions */
# .exchange-thumbs-feed-01 [class*=span] {
#     float:none;
#     margin-left:0;
# }
# .exchange-thumbs-feed-01 .trc_rbox_header {
#         line-height: 1.2em;
#         position: relative;
#         display: none;
#         width: auto;
# 	margin: 0px 0px 0px 0px;
# 	background: transparent;
# 	height: auto;
# 	background-color: transparent;
# 	box-sizing: initial;
# }
# .exchange-thumbs-feed-01 .trc_rbox_header_span .trc_header_right_column {
#         display: none;
# 	background: transparent;
# 	height: auto;
# }
# .exchange-thumbs-feed-01 .trc_rbox_header .logoDiv {
#         font-size: inherit;
#         line-height: normal;
# }
# .exchange-thumbs-feed-01 .logoDiv a {
#     font-size: 100%;
# }
# .exchange-thumbs-feed-01 .logoDiv a span {
#     display: inline;
#     color: #000000;
#     font-weight: normal;
#     font-size: 11px;
# }
# .exchange-thumbs-feed-01 .videoCube a {
#     padding: 0;
# }
# .exchange-thumbs-feed-01 .thumbBlock {
#     margin: 0;
# }
# .exchange-thumbs-feed-01 .video-label-box {
#     margin: 5px 5px 0px 5px;
#     height: 125px;
# }
# .exchange-thumbs-feed-01 .syndicatedItem .video-label-box {
#     margin: 5px 5px 0px 5px;
#     height: 125px;
# }
# .exchange-thumbs-feed-01 .videoCube .video-label-box .video-title {
#     text-decoration: none;
#     margin: 0;
# }
# .exchange-thumbs-feed-01 .videoCube:hover .video-label-box .video-title,
# .exchange-thumbs-feed-01 .videoCube:hover .video-label-box .video-description {
#     text-decoration: underline;
# }
# .exchange-thumbs-feed-01 .video-label-box .branding {
#     display: block;
# 	line-height: 27.0px;
# }
# .exchange-thumbs-feed-01 .syndicatedItem .branding {
#     line-height: 27.0px;
# }
# .exchange-thumbs-feed-01 .trc_header_left_column {
# 	background: transparent;
# 	height: auto;
# }
# .exchange-thumbs-feed-01 .trc_header_right_part {
# 	margin-top: 0px;
# }
# .exchange-thumbs-feed-01 .trc_rbox_header .logoDiv a {
# 	font-size: 100%;
# }
# .exchange-thumbs-feed-01 .trc_rbox_header .trc_header_ext {
# 	position: relative;
# 	top: auto;
# 	right: auto;
# }
#
# .grid-2r img {
#         max-width: none;
# }
#
# /* override bootstrap default span definitions */
# .grid-2r [class*='span'] {
#     float:none;
#     margin-left:0px;
# }
#
#
# .grid-2r .trc_rbox_header {
#         line-height: 1.2em;
#         position: relative;
#         height: auto;
# }
#
# .trc_rbox_container .grid-2r .trc_rbox_header {
#         padding-right:0px;
#         padding-left:0px;
# }
#
# .grid-2r .trc_rbox_header_span .trc_header_right_column {
#         display: none;
#         background: transparent;
#         height: auto;
# }
#
# .grid-2r .trc_rbox_header .logoDiv {
#         font-size: inherit;
#         line-height: 1.2em;
#         position: relative;
#         top: auto;
#         right: auto;
# }
#
# .grid-2r .logoDiv a {
#     vertical-align: baseline;
# }
#
# .grid-2r .logoDiv a span {
#     display: inline;
#     color: black;
#     font-weight: normal;
#     font-size: 10px;
# }
#
# .grid-2r .videoCube a {
#     padding: 0;
# }
#
# .grid-2r .thumbBlock {
#     margin: 0;
# }
#
# .trc_elastic .grid-2r .video-label-box {
#     height: 60.0px;
#         min-height: 45.0px;
# }
#
# .grid-2r .videoCube .video-label-box {
#     margin-top: 5px;
# }
#
# .grid-2r .videoCube .video-label-box .video-title {
#     text-decoration: none;
#     margin: 0;
# }
#
# .grid-2r .videoCube:hover .video-label-box .video-title {
#     text-decoration: underline;
# }
#
# .grid-2r .video-label-box .branding {
#     display: block;
# }
#
# .grid-2r .syndicatedItem .branding {
#     line-height: 15.0px;
# }
# .grid-2r .trc_header_left_column {
#         background: transparent;
#         display: inline;
#         height: auto;
# }
#
# .grid-2r .label-box-overlay {
#         background-color: #FFFFFF;
#         opacity: 0.8;
#         filter: alpha(opacity=80.0);
# }
#
# .grid-2r .trc_rbox_header .trc_header_ext {
#         position: relative;
#         top: auto;
#         right: auto;
# }
#     .horizontalx4 .videoCube .thumbnail-overlay {
#             width: 17px !important;
#             height: 22px !important;
#             left: 6px;
#             bottom: 4px;
#             display:block!important;
#     }
#     .horizontalx4 .videoCube:hover .thumbnail-overlay,
#     .horizontalx4 .videoCube_hover .thumbnail-overlay {
# 	background: url(http://www.bloomberg.com/images/tv/tvsprite.png) no-repeat scroll 0 -1192px;
#     }
#     div.horizontalx4-container {
#             background-color: inherit;
#     }
#     .horizontalx4, .horizontalx4 .trc_rbox_border_elm {
#             /* override background of version custom-css */
#             background-color: #161616;
#             background-image: none;
#     }
#
#     .horizontalx4 .trc_rbox_header div .logoDiv a span {
#         color: white;
# 	font-size: 9px;
# 	font-family: Arial,Helvetica,sans-serif;
# 	margin-right: 6px;
#     }
#
#     .horizontalx4 .trc_rbox_div {
#             *width: 614px;
#     }
#     .horizontalx4 .trc_rbox_div .videoCube,.horizontalx4 .trc_rbox_div .videoCube .video-label-box {
#             _width: 140px!important;
#     }
#
#     .horizontalx4 .trc_rbox_div .videoCube.horizontal {
#             _margin-left: expression(this.previousSibling == null ? '0' : '18px');
#     }
#
#    .horizontalx4 .trcPlay {
#             bottom: 5px;
#             font-size: 17px;
#             left: 7px;
#             position: absolute;
#             width:17px;
#             _width:17px!important;
#             font-size:1px;
#             color:transparent;
#             background: url(http://www.bloomberg.com/images/tv/tvsprite.png) no-repeat scroll 0 -1164px;
#             height: 24px;
#     }
#     .horizontalx4 .videoCube:hover .trcPlay,
#     .horizontalx4 .videoCube_hover .trcPlay {
#             background: url(http://www.bloomberg.com/images/tv/tvsprite.png) no-repeat scroll 0 -1192px;
#     }
#
#     .horizontalx4 .videoCube:hover .video-title,
#     .horizontalx4 .videoCube_hover .video-title {
#             text-decoration: underline;
#     }
#
#     .horizontalx4 .videoCube .thumbBlock {
#             position: relative;
#     }
#
#     .horizontalx4 .videoCube .video-label-box {
#             margin-top: 3px;
#     }
#     .horizontalx4 .videoCube .q .video-label-box,
#     .horizontalx4 .videoCube .q .video-title {
# 	display: inline !important;
#     }
#     .horizontalx4 .video-overlay {
#             background-color: black;
#             height: 22px;
#             opacity: 0.75;
#             filter: alpha(opacity=75);
#             position: absolute;
#             bottom: 0;
#             width: 138px;
#             z-index:10;
#     }
#
#     .horizontalx4 .videoCube .video-duration-detail {
#             position: absolute;
#             font-family: Arial, Helvetica, sans-serif;
#             bottom: 4px;
#             width: 135px;
#             line-height:13px;
#             text-align: right;
#             padding-right: 3px;
#             z-index:11;
#     }
#
#     .horizontalx4 .trc_rbox_outer{width:614px!important;}
#
# .mobile-thumbnails-h img {
#         max-width: none;
# }
#
# /* override bootstrap default span definitions */
# .mobile-thumbnails-h [class*=span] {
#     float:none;
#     margin-left:0;
# }
#
#
# .mobile-thumbnails-h .trc_rbox_header {
#         line-height: 1.2em;
#         position: relative;
#         display: block;
#         width: auto;
# 	margin: 0px 0px 0px 0px;
# 	background: transparent;
# 	height: auto;
# 	background-color: transparent;
# 	padding: 0 0 6px 0;
# 	box-sizing: initial;
# }
#
# .mobile-thumbnails-h .trc_rbox_header_span .trc_header_right_column {
#         display: none;
# 	background: transparent;
# 	height: auto;
# }
#
# .mobile-thumbnails-h .trc_rbox_header .logoDiv {
#         font-size: inherit;
#         line-height: normal;
# }
#
# .mobile-thumbnails-h .logoDiv a {
#     font-size: 100%;
# }
#
# .mobile-thumbnails-h .logoDiv a span {
#     display: inline;
#     color: #000000;
#     font-weight: normal;
#     font-size: 11.0px;
# }
#
# .mobile-thumbnails-h .videoCube a {
#     padding: 0;
# }
#
# .mobile-thumbnails-h .thumbBlock {
#     margin: 0;
# }
#
# .trc_elastic .mobile-thumbnails-h .video-label-box {
#     height: 88.0px;
# }
#
# .mobile-thumbnails-h .videoCube .video-label-box {
#     margin-top: 5px;
# }
#
# .mobile-thumbnails-h .videoCube .video-label-box .video-title {
#     text-decoration: none;
#     margin: 0;
# }
#
# .mobile-thumbnails-h .videoCube:hover .video-label-box .video-title {
#     text-decoration: underline;
# }
#
# .mobile-thumbnails-h .video-label-box .branding {
#     display: block;
# }
#
# .mobile-thumbnails-h .syndicatedItem .branding {
#     line-height: 22.0px;
# }
# .mobile-thumbnails-h .trc_header_left_column {
# 	width: 48%;
# 	display: inline-block;
# 	background: transparent;
# 	height: auto;
# }
#
# .mobile-thumbnails-h .trc_header_right_part {
# 	margin-top: 0px;
# }
#
# .mobile-thumbnails-h .trc_rbox_header .logoDiv a {
# 	font-size: 100%;
# }
#
# .mobile-thumbnails-h .trc_rbox_header .trc_header_ext {
# 	position: relative;
# 	top: auto;
# 	right: auto;
# }
# .organic-thumbnails-feed img {
#         max-width: none;
# }
#
# /* override bootstrap default span definitions */
# .organic-thumbnails-feed [class*=span] {
#     float:none;
#     margin-left:0;
# }
#
#
# .organic-thumbnails-feed .trc_rbox_header {
#         line-height: 1.2em;
#         position: relative;
#         display: none;
#         width: auto;
# 	margin: 0px 0px 0px 0px;
# 	background: transparent;
# 	height: auto;
# 	background-color: transparent;
# 	box-sizing: initial;
# }
#
# .organic-thumbnails-feed .trc_rbox_header_span .trc_header_right_column {
#         display: none;
# 	background: transparent;
# 	height: auto;
# }
#
# .organic-thumbnails-feed .trc_rbox_header .logoDiv {
#         font-size: inherit;
#         line-height: normal;
# }
#
# .organic-thumbnails-feed .logoDiv a {
#     font-size: 100%;
# }
#
# .organic-thumbnails-feed .logoDiv a span {
#     display: inline;
#     color: #000000;
#     font-weight: normal;
#     font-size: 11.0px;
# }
#
# .organic-thumbnails-feed .videoCube a {
#     padding: 0;
# }
#
# .organic-thumbnails-feed .thumbBlock {
#     margin: 0;
# }
#
# .organic-thumbnails-feed .video-label-box {
#     margin: 5px 5px 0px 5px;
#     height: 44px;
# }
#
# .organic-thumbnails-feed .syndicatedItem .video-label-box {
#     margin: 5px 5px 0px 5px;
#     height: 44px;
# }
#
# .organic-thumbnails-feed .videoCube .video-label-box .video-title {
#     text-decoration: none;
#     margin: 0;
# }
#
# .organic-thumbnails-feed .videoCube:hover .video-label-box .video-title,
# .organic-thumbnails-feed .videoCube:hover .video-label-box .video-description {
#     text-decoration: underline;
# }
#
# .organic-thumbnails-feed .video-label-box .branding {
#     display: block;
# 	line-height: 27.0px;
# }
#
# .organic-thumbnails-feed .syndicatedItem .branding {
#     line-height: 27.0px;
# }
# .organic-thumbnails-feed .trc_header_left_column {
# 	background: transparent;
# 	height: auto;
# }
#
# .organic-thumbnails-feed .trc_header_right_part {
# 	margin-top: 0px;
# }
#
# .organic-thumbnails-feed .trc_rbox_header .logoDiv a {
# 	font-size: 100%;
# }
#
# ...
# b):a.write("\x3c","p","\x3e\x3c",'img src\x3d"',b,'" height\x3d"1" width\x3d"1" alt\x3d"*"',"\x3e\x3c","/p","\x3e")}"undefined"==typeof _comscore&amp;&amp;(_comscore=[]);
# (function(){var b="length",f=self,a=f.encodeURIComponent?encodeURIComponent:escape,c=".scorecardresearch.com",u="//app"+c+"/s2e/invite",q=Math,m="script",r="width",t=/c2=(\d*)&amp;/,d,n=function(e){if(e){var g=[];var f=0,h="";for(l in e){var k=typeof e[l];if("string"==k||"number"==k)g[g[b]]=l+"\x3d"+a(e[l]),"c2"==l?h=e[l]:"c1"==l&amp;&amp;(f=1)}if(!(0&gt;=g[b]||""==h)){var d=e.options||{};d.d=d.d||document;if("string"==typeof d.url_append){e=d.url_append.replace(/&amp;/,"\x26").split("\x26");var l=0;for(k=e[b];l&lt;k;l++)h=
# e[l].split("\x3d"),2==h[b]&amp;&amp;(g[g[b]]=h[0]+"\x3d"+a(h[1]))}g=["http","s"==d.d.URL.charAt(4)?"s://sb":"://b",c,"/b?",f?"":"c1\x3d2\x26",g.join("\x26").replace(/&amp;$/,"")];udm_(g.join(""),function(){var a=d;if(!(0&gt;this.src.indexOf("c1\x3d2"))&amp;&amp;a.d.createElement&amp;&amp;(a.force_script_extension||2==this[r]&amp;&amp;this.height&gt;q.round(100*q.random()))){var b=a.d.createElement(m),c=a.d.getElementsByTagName(m)[0];a=[a.script_extension_url||u,"?c2\x3d",this.src.match(t)[1]].join("");c&amp;&amp;(b.src=a,b.async=!0,c.parentNode.insertBefore(b,
# c))}})}}},p=function(a){a=a||_comscore;for(var c=0,d=a[b];c&lt;d;c++)n(a[c]);_comscore=[]};p();(d=f.COMSCORE)?(d.purge=p,d.beacon=n):COMSCORE={purge:p,beacon:n}})();
# (function(){function b(a,b){for(var c=a.toString();c.length&lt;b;)c="0"+c;return c}function f(){var a=new Date;return a.getFullYear()+"-"+b(a.getMonth(),2)+"-"+b(a.getDate(),2)+" "+b(a.getHours(),2)+":"+b(a.getMinutes(),2)+":"+b(a.getSeconds(),2)}var a={name:google_tag_manager["GTM-MNTH5N"].macro(15),bb_localhour:f(),bb_c_type:google_tag_manager["GTM-MNTH5N"].macro(16),bb_cg_3:window.document.title,bb_brand:google_tag_manager["GTM-MNTH5N"].macro(17)||google_tag_manager["GTM-MNTH5N"].macro(18),bb_screensize:window.screen.availWidth+"x"+window.screen.availHeight,bb_viewport:window.innerWidth+
# "x"+window.innerHeight,bb_focus:google_tag_manager["GTM-MNTH5N"].macro(19),bb_refresh:"true"===google_tag_manager["GTM-MNTH5N"].macro(20)?"1":"0",bb_region:google_tag_manager["GTM-MNTH5N"].macro(21)||"US",bb_exp:google_tag_manager["GTM-MNTH5N"].macro(22)||"AMER",c1:2,c2:"3005059",c7:window.document.URL,c8:window.document.title,c9:"",bb_userid:google_tag_manager["GTM-MNTH5N"].macro(23),ns_site:google_tag_manager["GTM-MNTH5N"].macro(26)};google_tag_manager["GTM-MNTH5N"].macro(27)&amp;&amp;(a.bb_cg_2=google_tag_manager["GTM-MNTH5N"].macro(28));google_tag_manager["GTM-MNTH5N"].macro(29)&amp;&amp;(a.bb_groupid=google_tag_manager["GTM-MNTH5N"].macro(30),a.bb_attributor=google_tag_manager["GTM-MNTH5N"].macro(31),
# a.bb_author=google_tag_manager["GTM-MNTH5N"].macro(32),a.bb_pub_d=google_tag_manager["GTM-MNTH5N"].macro(33),a.bb_cg_3=google_tag_manager["GTM-MNTH5N"].macro(34),a.bb_transporter="true"===google_tag_manager["GTM-MNTH5N"].macro(35)?"1":"0",a.bb_slug=google_tag_manager["GTM-MNTH5N"].macro(36),a.bb_topic1=google_tag_manager["GTM-MNTH5N"].macro(37),a.bb_topic2=google_tag_manager["GTM-MNTH5N"].macro(38),a.bb_people=google_tag_manager["GTM-MNTH5N"].macro(39),a.bb_category=google_tag_manager["GTM-MNTH5N"].macro(40),a.legacy_bb_contentage=google_tag_manager["GTM-MNTH5N"].macro(43),google_tag_manager["GTM-MNTH5N"].macro(44)&amp;&amp;(a.bb_topic_opinion=google_tag_manager["GTM-MNTH5N"].macro(45)));COMSCORE.beacon(a)})();</script></div><div id="paywall-banner">
# <div class="banner__32aaf6f6 yellow__53d92cc8" data-state="collapsed">
# <div class="splitContainer__d24eddb7 desktop__593c43cd">
# <div class="left__0be47945">
# <span class="importantMedium__8da5e57f bold__7218ac15">Want more markets news and insights? </span><span class="normal__c36b500e importantMedium__8da5e57f">Subscribe for unlimited access.</span>
# </div>
# <div class="right__ca6a8a7b">
# <a class="buttonLink__bbf8051a bold__7218ac15 medium__8b0fef08 more__df93d005 whiteOnBlack__5e1ed97f" href="javascript:function() { return false; }" rel="noopener noreferrer" target="_blank">
#         Learn more  <span class="expandArrow__720123cc"></span>
# </a>
# <span class="less__8d5fd7af closeIcon__23b87949"></span>
# </div>
# </div>
# <div class="splitContainer__d24eddb7 mobile__6f594664">
# <div class="left__0be47945">
# <span class="importantMedium__8da5e57f bold__7218ac15">Want more markets news and insights? </span><span class="normal__c36b500e importantMedium__8da5e57f">Subscribe for unlimited access.</span>
# </div>
# <div class="right__d0f3582e right__ca6a8a7b">
# <span class="more__df93d005 openIcon__4290ed77"></span>
# <span class="less__8d5fd7af closeIcon__23b87949"></span>
# </div>
# </div>
# <div class="splitContainer__d24eddb7 tablet__cd4e08ed">
# <div class="left__0be47945">
# <span class="importantMedium__8da5e57f bold__7218ac15">Want more markets news and insights? </span><span class="normal__c36b500e importantMedium__8da5e57f">Subscribe for unlimited access.</span>
# </div>
# <div class="right__d0f3582e right__ca6a8a7b">
# <span class="more__df93d005 openIcon__4290ed77"></span>
# <span class="less__8d5fd7af closeIcon__23b87949"></span>
# </div>
# </div>
# </div>
# <div class="bannerContent__820eb933 yellow__53d92cc8">
# <div class="splitContainer__d24eddb7 desktop__593c43cd">
# <div class="left__0be47945">
# <div class="bold__7218ac15 importantMedium__8da5e57f">
#                 Get unlimited access to Bloomberg's fact-based journalism on all of your devices.
#             </div>
# <div class="small__dedb7a5c subscriberText__44f4191b logInFont__1329fd36">
#                 Already a subscriber?
#
#     <a class="link__3a24c78a log-in-link">
#         Sign in here
#     </a>
# </div>
# <div class="small__dedb7a5c logInFont__1329fd36">
# <span class="terminal__328ab50f"></span>
# <span>Bloomberg Anywhere clients get
#     <a class="link__3a24c78a free-access-link">
#         free access
#     </a>
# </span>
# </div>
# </div>
# <div class="right__ca6a8a7b">
# <div class="splitContainer__d24eddb7 desktop__593c43cd">
# <div class="left__0be47945">
# <div class="deviceImage__578745e8"></div>
# </div>
# <div class="right__ca6a8a7b">
# <a class="link__3a24c78a" href="https://www.bloomberg.com/subscriptions?in_source=markets-meter" target="_blank">
# <object>
# <div class="offerBox__c55ddd26 yellow__53d92cc8">
# <div class="bold__7218ac15 importantMedium__8da5e57f offerText__703d27fd">
#                             Limited time offer
#                         </div>
# <div>
# <a class="buttonLink__bbf8051a subscribeButton__e5a21327 whiteOnBlack__5e1ed97f" data-app="fence" data-category="Metering" data-label="meter_subscribe" href="https://www.bloomberg.com/subscriptions?in_source=markets-meter" rel="noopener noreferrer" target="_blank">
#         Subscribe now
#     </a>
# </div>
# </div>
# </object>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="centeredContainer__12554d15 mobile__635c4c48">
# <div class="bold__7218ac15 offerText__703d27fd">
#             Get unlimited access to Bloomberg's fact-based journalism on all of your devices.
#         </div>
# <div>
# <a class="buttonLink__bbf8051a subscribeButton__e5a21327 whiteOnBlack__5e1ed97f" data-app="fence" data-category="Metering" data-label="meter_subscribe" href="https://www.bloomberg.com/subscriptions?in_source=markets-meter" rel="noopener noreferrer" target="_blank">
#         Subscribe now
#     </a>
# </div>
# <div class="small__dedb7a5c subscriberText__44f4191b logInFont__1329fd36">
# <span>Already a subscriber?</span>
# <span>
# <a class="link__3a24c78a log-in-link">
#         Sign in here
#     </a>
# </span>
# </div>
# </div>
# <div class="centeredContainer__12554d15 tablet__aac7af11">
# <div class="bold__7218ac15 offerText__703d27fd">
#             Get unlimited access to Bloomberg's fact-based journalism on all of your devices.
#         </div>
# <div>
# <a class="buttonLink__bbf8051a subscribeButton__e5a21327 whiteOnBlack__5e1ed97f" data-app="fence" data-category="Metering" data-label="meter_subscribe" href="https://www.bloomberg.com/subscriptions?in_source=markets-meter" rel="noopener noreferrer" target="_blank">
#         Subscribe now
#     </a>
# </div>
# <div class="small__dedb7a5c subscriberText__44f4191b logInFont__1329fd36">
# <span>Already a subscriber?</span>
# <span>
# <a class="link__3a24c78a log-in-link">
#         Sign in here
#     </a>
# </span>
# </div>
# </div>
# </div>
# </div><script src="https://mb.moatads.com/yi.js?ud=0&amp;qn=(%2BIb%7Cj8o%3FJei%2F*%5EJqD(aD%5Bqir1fcSC%3AU%3FWOvTh%7CzFK%3F%5B%22l!j%3F%5DNCLmT%23%3CF%2B1S%2BapY%3C%5ECUo1vOJ%3D%3A9)NpU7efcH1p%3Cu%60_PyDN(%2BWx*h~%3F03*%5B)%2C2iVSWfV%7D%2F%2FRA7R.eJKx%7Ci6sGm!ryh%7Cek)3.%5BqC%7Dq%7CRgh%2C%7BLTVTy%5EzmZpe4tE0b15%7CQjw%60.%7Bi%24J)%2C4i8ocS!%5BFZKU37B%2BMm1TFG5%3D_%40NVktoDtX%3EAVE&amp;qp=10000&amp;is=&amp;iv=7&amp;qt=0&amp;gz=1&amp;hh=0&amp;hn=0&amp;tw=null&amp;qc=30&amp;qd=42&amp;qf=1200&amp;qe=537&amp;qh=1200&amp;qg=660&amp;qm=240&amp;qa=0&amp;qb=0&amp;qi=0&amp;qj=0&amp;po=1-0020002000002120&amp;qr=0&amp;url=https%3A%2F%2Fwww.bloomberg.com%2Fquote%2F140910%3AKS&amp;confidence=2&amp;pcode=bloombergprebidheader853620778109&amp;callback=MoatNadoAllJsonpRequest_8699201" type="text/javascript"></script><script src="https://geo.moatads.com/n.js?e=35&amp;ud=0&amp;qn=(%2BIb%7Cj8o%3FJei%2F*%5EJqD(aD%5Bqir1fcSC%3AU%3FWOvTh%7CzFK%3F%5B%22l!j%3F%5DNCLmT%23%3CF%2B1S%2BapY%3C%5ECUo1vOJ%3D%3A9)NpU7efcH1p%3Cu%60_PyDN(%2BWx*h~%3F03*%5B)%2C2iVSWfV%7D%2F%2FRA7R.eJKx%7Ci6sGm!ryh%7Cek)3.%5BqC%7Dq%7CRgh%2C%7BLTVTy%5EzmZpe4tE0b15%7CQjw%60.%7Bi%24J)%2C4i8ocS!%5BFZKU37B%2BMm1TFG5%3D_%40NVktoDtX%3EAVE&amp;qp=10000&amp;is=&amp;iv=7&amp;qt=0&amp;gz=1&amp;hh=0&amp;hn=0&amp;tw=&amp;qc=30&amp;qd=42&amp;qf=1200&amp;qe=537&amp;qh=1200&amp;qg=660&amp;qm=240&amp;qa=0&amp;qb=0&amp;qi=0&amp;qj=0&amp;po=1-0020002000002120&amp;qr=0&amp;i=BLOOMBERG_PREBID_HEADER1&amp;hp=1&amp;kq=2&amp;hq=0&amp;hs=0&amp;hu=0&amp;hr=0&amp;ht=1&amp;dnt=0&amp;bq=11&amp;f=0&amp;j=&amp;o=3&amp;t=1554848135596&amp;de=316609251876&amp;rx=741379089323&amp;m=0&amp;ar=79f0d37-clean&amp;q=1&amp;cb=0&amp;cu=1554848135596&amp;ll=7&amp;lm=0&amp;ln=0&amp;em=0&amp;en=0&amp;d=undefined%3Aundefined%3Aundefined%3Aundefined&amp;zMoatAdUnit1=-&amp;zMoatAdUnit2=-&amp;zMoatAdUnit3=-&amp;qs=1&amp;bo=undefined&amp;bd=undefined&amp;gw=bloombergprebidheader853620778109&amp;fd=1&amp;ac=1&amp;it=500&amp;fs=161552&amp;na=1460162551&amp;cs=0&amp;callback=MoatSuperV26.gna370610" type="text/javascript"></script><a aria-hidden="true" href="/quote/140910:KS?_pxhcb=1554848135562" rel="nofollow" style="width: 0px; height: 0px; font-size: 0px; line-height: 0;" tabindex="-1" target="_blank"></a><script src="//www.googletagservices.com/tag/js/gpt.js"></script>
# <iframe src="//i.liadm.com/s/c/a-015y?s=&amp;cim=&amp;ps=true&amp;ls=true&amp;duid=a-015y--8d44ed83-81cf-4d86-bb8f-8a0c89ace05a&amp;domainSessionId=&amp;ppid=0&amp;euns=0&amp;ci=0&amp;version=sc-2.2.2&amp;nosync=true&amp;" style="display: none; width: 0px; height: 0px; border: 0px;"></iframe>
# <script async="" src="//imasdk.googleapis.com/js/sdkloader/ima3.js"></script><script async="" src="//s3.amazonaws.com/bvp-staging/projector/v0.11.142/vendor.js"></script><script async="" src="https://js.spotx.tv/directsdk/v1/236177.js"></script><script async="" src="//s3.amazonaws.com/bvp-staging/projector/v0.11.142/app.js"></script><span><iframe class="trc-hidden" height="0" id="trc-pixel-iframe-2287" name="trc-pixel-iframe-2287" style="display:none" width="0"></iframe></span><span><iframe class="trc-hidden" height="0" id="trc-pixel-iframe-7682" name="trc-pixel-iframe-7682" style="display:none" width="0"></iframe></span><script src="https://px.ads.linkedin.com/collect/?time=1554848136715&amp;pid=403593%2C155577&amp;url=https%3A%2F%2Fwww.bloomberg.com%2Fquote%2F140910%3AKS&amp;fmt=js&amp;s=1" type="text/javascript"></script><iframe aria-hidden="true" id="LOTCCFrame_1554848136726" role="presentation" src="https://bcp.crwdcntrl.net/5/c=12098/rand=262415026/pv=y/cmp=1/cmpto=250/int=%23OpR%2380088%23Total%20Site%20Traffic%20%3A%20https%3A%2F%2Fwww.bloomberg.com/int=%23OpR%2381954%23dataLayer%20%3A%20adcode%20%3A%20markets%2Fquote/int=%23OpR%2381967%23dataLayer%20%3A%20brand%20%3A%20markets/int=%23OpR%2381968%23dataLayer%20%3A%20contentType%20%3A%20marketdata-quote-common_stock/int=%23OpR%2381970%23dataLayer%20%3A%20pageType%20%3A%20marketdata/seg=%23OpR%2382105%23Ticker%20%3A%20140910%3AKS/rt=ifr" style="border: 0px; width: 0px; height: 0px; display: block;" tabindex="-1" title="empty"></iframe><script src="https://analytics.twitter.com/i/adsct?p_id=Twitter&amp;p_user_id=0&amp;txn_id=ny9oj&amp;events=%5B%5B%22pageview%22%2Cnull%5D%5D&amp;tw_sale_amount=0&amp;tw_order_quantity=0&amp;tw_iframe_status=0&amp;tpx_cb=twttr.conversion.loadPixels&amp;tw_document_href=https%3A%2F%2Fwww.bloomberg.com%2Fquote%2F140910%3AKS" type="text/javascript"></script><script src="https://analytics.twitter.com/i/adsct?p_id=Twitter&amp;p_user_id=0&amp;txn_id=nyu3t&amp;events=%5B%5B%22pageview%22%2Cnull%5D%5D&amp;tw_sale_amount=0&amp;tw_order_quantity=0&amp;tw_iframe_status=0&amp;tpx_cb=twttr.conversion.loadPixels&amp;tw_document_href=https%3A%2F%2Fwww.bloomberg.com%2Fquote%2F140910%3AKS" type="text/javascript"></script><script src="https://analytics.twitter.com/i/adsct?p_id=Twitter&amp;p_user_id=0&amp;txn_id=nz64l&amp;events=%5B%5B%22pageview%22%2Cnull%5D%5D&amp;tw_sale_amount=0&amp;tw_order_quantity=0&amp;tw_iframe_status=0&amp;tpx_cb=twttr.conversion.loadPixels&amp;tw_document_href=https%3A%2F%2Fwww.bloomberg.com%2Fquote%2F140910%3AKS" type="text/javascript"></script><script src="https://analytics.twitter.com/i/adsct?p_id=Twitter&amp;p_user_id=0&amp;txn_id=nzex3&amp;events=%5B%5B%22pageview%22%2Cnull%5D%5D&amp;tw_sale_amount=0&amp;tw_order_quantity=0&amp;tw_iframe_status=0&amp;tpx_cb=twttr.conversion.loadPixels&amp;tw_document_href=https%3A%2F%2Fwww.bloomberg.com%2Fquote%2F140910%3AKS" type="text/javascript"></script><script src="https://analytics.twitter.com/i/adsct?p_id=Twitter&amp;p_user_id=0&amp;txn_id=nyu3t&amp;events=%5B%5B%22pageview%22%2Cnull%5D%5D&amp;tw_sale_amount=0&amp;tw_order_quantity=0&amp;tw_iframe_status=0&amp;tpx_cb=twttr.conversion.loadPixels&amp;tw_document_href=https%3A%2F%2Fwww.bloomberg.com%2Fquote%2F140910%3AKS" type="text/javascript"></script><script async="" src="//ad.crwdcntrl.net/5/c=12097/pe=y/rand=3232/callback=bvpLotame.jsonpCallback_8434"></script></body></html>>

# %%
print(soup.find("section",{"class":re.compile("left__.{0,10} description__.{0,10}")}).text)
# Out:
# A Self-Administered Real Estate Investment Trust Inc. purchases properties and residential buildings. The Company invests in industrial plants, office buildings, hotel, residential buildings, and other real estates.
